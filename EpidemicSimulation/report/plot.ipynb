# %%
x = [1,2,4,8,16]
y1 = [0.099034,0.086420,0.099596,0.099034,0.129375]
y2 = [1.180612,1.289690,1.377647,1.350268,1.225976]
y3 = [264.4338707,266.809695,268.477748,261.531911,258.611423]

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.plot(x, y1, '-',label="1000 nodes")
plt.plot(x, y2, '-',label="10000 nodes")
plt.ylabel("Time(second)")
plt.xlabel("Thread Number")

plt.title("Performance Plot - different graph size")
plt.legend()

# %%
plt.plot(x, y3, '-',label="100000 nodes")
plt.ylabel("Time(second)")
plt.xlabel("Thread Number")

plt.title("Performance Plot - different graph size")
plt.legend()
